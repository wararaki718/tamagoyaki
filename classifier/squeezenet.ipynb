# %%
import os
import numpy as np
from cnn_finetune import make_model
import pandas as pd
from skimage import io
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import Dataset
from torchvision import transforms, utils

# %% [markdown]
# https://pytorch.org/tutorials/beginner/data_loading_tutorial.html#dataset-class

# %%
model = make_model('squeezenet1_0', num_classes=2, pretrained=True, input_size=(128, 128))
device = torch.device('cuda')
model = model.to(device)
# Out:
# /opt/conda/lib/python3.6/site-packages/torchvision/models/squeezenet.py:94: UserWarning: nn.init.kaiming_uniform is now deprecated in favor of nn.init.kaiming_uniform_.
#   init.kaiming_uniform(m.weight.data)
# /opt/conda/lib/python3.6/site-packages/torchvision/models/squeezenet.py:92: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
#   init.normal(m.weight.data, mean=0.0, std=0.01)

# %%
class MyDataSet(Dataset):
    def __init__(self, csv_path, root_dir, transform=None):
        self.data_df = pd.read_csv(csv_path)
        self.root_dir = root_dir
        
        if transform is None:
            self.transform = transforms.Compose([
                transforms.ToTensor(),
                transforms.Normalize(
                mean=model.original_model_info.mean,
                std=model.original_model_info.std),
            ])
        else:
            self.transform = transform
        
    def __len__(self):
        return self.data_df.shape[0]
    
    def __getitem__(self, idx):
        image_name = os.path.join(self.root_dir, self.data_df.iloc[idx, 0])
        image = io.imread(image_name)
        label = self.data_df.iloc[idx, 1]
        return self.transform(image), int(label)
    
    def get_full_data(self):
        image_names = [
            os.path.join(self.root_dir, self.data_df.iloc[idx, 0]) for idx in range(self.data_df.shape[0])
        ]
        images = [io.imread(path) for path in image_names]
        return images

# %%
train_set = MyDataSet('../images/train_data.csv', '../images/resize/data/')
train_loader = torch.utils.data.DataLoader(train_set, shuffle=True)

# %%
test_set = MyDataSet('../images/test_data.csv', '../images/resize/data/')
test_loader = torch.utils.data.DataLoader(test_set, shuffle=False)

# %% [markdown]
# refs
#
# https://github.com/creafz/pytorch-cnn-finetune/blob/master/examples/cifar10.py

# %%
criterion = nn.CrossEntropyLoss()
#optimizer = optim.SGD(model.parameters(), lr=1e-5, momentum=0.9)
optimizer = optim.Adam(model.parameters(), lr=1e-5)

# %%
def train(epoch):
    total_loss = 0
    total_size = 0
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        total_loss += loss.item()
        total_size += data.size(0)
        loss.backward()
        optimizer.step()
        if (batch_idx+1) % 20 == 0 or (batch_idx+1)==len(train_loader):
            progress = 100. * (batch_idx+1) / len(train_loader)
            average_loss = total_loss / total_size
            print(f'Train Epoch: {epoch+1} [{(batch_idx+1) * len(data)}/{len(train_loader.dataset)} ({progress:.0f}%)]\tAverage loss: {average_loss:.6f}')

# %%
def test():
    model.eval()
    test_loss = 0
    correct = 0
    outputs = []
    targets = []
    with torch.no_grad():
        for data, target in test_loader:
            targets.append(target)
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += criterion(output, target).item()
            pred = output.data.max(1, keepdim=True)[1]
            correct += pred.eq(target.data.view_as(pred)).long().cpu().sum().item()
            outputs.append(output.cpu().detach().numpy())

    test_loss /= len(test_loader.dataset)
    accuracy = 100. * correct / len(test_loader.dataset)
    print(f'\nTest set: Average loss: {test_loss:.4f}, Accuracy: {correct}/{len(test_loader.dataset)} ({accuracy:.0f}%)\n')
    return outputs, targets

# %%
for epoch in range(10):
    train(epoch)
    test()
# Out:
# Train Epoch: 1 [20/173 (12%)]	Average loss: 1.394515
# Train Epoch: 1 [40/173 (23%)]	Average loss: 1.001053
# Train Epoch: 1 [60/173 (35%)]	Average loss: 1.015598
# Train Epoch: 1 [80/173 (46%)]	Average loss: 0.941396
# Train Epoch: 1 [100/173 (58%)]	Average loss: 0.884307
# Train Epoch: 1 [120/173 (69%)]	Average loss: 0.829828
# Train Epoch: 1 [140/173 (81%)]	Average loss: 0.798935
# Train Epoch: 1 [160/173 (92%)]	Average loss: 0.755887
# Train Epoch: 1 [173/173 (100%)]	Average loss: 0.725030
#
# Test set: Average loss: 0.3253, Accuracy: 65/76 (86%)
#
# Train Epoch: 2 [20/173 (12%)]	Average loss: 0.639756
# Train Epoch: 2 [40/173 (23%)]	Average loss: 0.469551
# Train Epoch: 2 [60/173 (35%)]	Average loss: 0.413469
# Train Epoch: 2 [80/173 (46%)]	Average loss: 0.421425
# Train Epoch: 2 [100/173 (58%)]	Average loss: 0.427409
# Train Epoch: 2 [120/173 (69%)]	Average loss: 0.408626
# Train Epoch: 2 [140/173 (81%)]	Average loss: 0.428207
# Train Epoch: 2 [160/173 (92%)]	Average loss: 0.404450
# Train Epoch: 2 [173/173 (100%)]	Average loss: 0.403003
#
# Test set: Average loss: 0.2568, Accuracy: 68/76 (89%)
#
# Train Epoch: 3 [20/173 (12%)]	Average loss: 0.244245
# Train Epoch: 3 [40/173 (23%)]	Average loss: 0.260684
# Train Epoch: 3 [60/173 (35%)]	Average loss: 0.294545
# Train Epoch: 3 [80/173 (46%)]	Average loss: 0.273541
# Train Epoch: 3 [100/173 (58%)]	Average loss: 0.311448
# Train Epoch: 3 [120/173 (69%)]	Average loss: 0.329395
# Train Epoch: 3 [140/173 (81%)]	Average loss: 0.310236
# Train Epoch: 3 [160/173 (92%)]	Average loss: 0.284815
# Train Epoch: 3 [173/173 (100%)]	Average loss: 0.273126
#
# Test set: Average loss: 0.2041, Accuracy: 70/76 (92%)
#
# Train Epoch: 4 [20/173 (12%)]	Average loss: 0.424165
# Train Epoch: 4 [40/173 (23%)]	Average loss: 0.249567
# Train Epoch: 4 [60/173 (35%)]	Average loss: 0.210436
# Train Epoch: 4 [80/173 (46%)]	Average loss: 0.189897
# Train Epoch: 4 [100/173 (58%)]	Average loss: 0.182182
# Train Epoch: 4 [120/173 (69%)]	Average loss: 0.178251
# Train Epoch: 4 [140/173 (81%)]	Average loss: 0.185856
# Train Epoch: 4 [160/173 (92%)]	Average loss: 0.178267
# Train Epoch: 4 [173/173 (100%)]	Average loss: 0.194492
#
# Test set: Average loss: 0.1823, Accuracy: 70/76 (92%)
#
# Train Epoch: 5 [20/173 (12%)]	Average loss: 0.107549
# Train Epoch: 5 [40/173 (23%)]	Average loss: 0.103252
# Train Epoch: 5 [60/173 (35%)]	Average loss: 0.170296
# Train Epoch: 5 [80/173 (46%)]	Average loss: 0.163453
# Train Epoch: 5 [100/173 (58%)]	Average loss: 0.147655
# Train Epoch: 5 [120/173 (69%)]	Average loss: 0.144176
# Train Epoch: 5 [140/173 (81%)]	Average loss: 0.132828
# Train Epoch: 5 [160/173 (92%)]	Average loss: 0.121430
# Train Epoch: 5 [173/173 (100%)]	Average loss: 0.118262
#
# Test set: Average loss: 0.1777, Accuracy: 72/76 (95%)
#
# Train Epoch: 6 [20/173 (12%)]	Average loss: 0.050219
# Train Epoch: 6 [40/173 (23%)]	Average loss: 0.045800
# Train Epoch: 6 [60/173 (35%)]	Average loss: 0.044679
# Train Epoch: 6 [80/173 (46%)]	Average loss: 0.049398
# Train Epoch: 6 [100/173 (58%)]	Average loss: 0.063437
# Train Epoch: 6 [120/173 (69%)]	Average loss: 0.056737
# Train Epoch: 6 [140/173 (81%)]	Average loss: 0.060244
# Train Epoch: 6 [160/173 (92%)]	Average loss: 0.081215
# Train Epoch: 6 [173/173 (100%)]	Average loss: 0.083277
#
# Test set: Average loss: 0.2141, Accuracy: 69/76 (91%)
#
# Train Epoch: 7 [20/173 (12%)]	Average loss: 0.069221
# Train Epoch: 7 [40/173 (23%)]	Average loss: 0.052337
# Train Epoch: 7 [60/173 (35%)]	Average loss: 0.053107
# Train Epoch: 7 [80/173 (46%)]	Average loss: 0.072153
# Train Epoch: 7 [100/173 (58%)]	Average loss: 0.069732
# Train Epoch: 7 [120/173 (69%)]	Average loss: 0.064841
# Train Epoch: 7 [140/173 (81%)]	Average loss: 0.060717
# Train Epoch: 7 [160/173 (92%)]	Average loss: 0.058046
# Train Epoch: 7 [173/173 (100%)]	Average loss: 0.054984
#
# Test set: Average loss: 0.1905, Accuracy: 70/76 (92%)
#
# Train Epoch: 8 [20/173 (12%)]	Average loss: 0.033152
# Train Epoch: 8 [40/173 (23%)]	Average loss: 0.037637
# Train Epoch: 8 [60/173 (35%)]	Average loss: 0.031304
# Train Epoch: 8 [80/173 (46%)]	Average loss: 0.030007
# Train Epoch: 8 [100/173 (58%)]	Average loss: 0.026866
# Train Epoch: 8 [120/173 (69%)]	Average loss: 0.043453
# Train Epoch: 8 [140/173 (81%)]	Average loss: 0.040707
# Train Epoch: 8 [160/173 (92%)]	Average loss: 0.038894
# Train Epoch: 8 [173/173 (100%)]	Average loss: 0.039553
#
# Test set: Average loss: 0.1940, Accuracy: 70/76 (92%)
#
# Train Epoch: 9 [20/173 (12%)]	Average loss: 0.007487
# Train Epoch: 9 [40/173 (23%)]	Average loss: 0.015193
# Train Epoch: 9 [60/173 (35%)]	Average loss: 0.017407
# Train Epoch: 9 [80/173 (46%)]	Average loss: 0.018272
# Train Epoch: 9 [100/173 (58%)]	Average loss: 0.021040
# Train Epoch: 9 [120/173 (69%)]	Average loss: 0.027266
# Train Epoch: 9 [140/173 (81%)]	Average loss: 0.028055
# Train Epoch: 9 [160/173 (92%)]	Average loss: 0.025287
# Train Epoch: 9 [173/173 (100%)]	Average loss: 0.028442
#
# Test set: Average loss: 0.2045, Accuracy: 70/76 (92%)
#
# Train Epoch: 10 [20/173 (12%)]	Average loss: 0.048555
# Train Epoch: 10 [40/173 (23%)]	Average loss: 0.031120
# Train Epoch: 10 [60/173 (35%)]	Average loss: 0.026791
# Train Epoch: 10 [80/173 (46%)]	Average loss: 0.023281
# Train Epoch: 10 [100/173 (58%)]	Average loss: 0.021816
# Train Epoch: 10 [120/173 (69%)]	Average loss: 0.020200
# Train Epoch: 10 [140/173 (81%)]	Average loss: 0.019731
# Train Epoch: 10 [160/173 (92%)]	Average loss: 0.018410
# Train Epoch: 10 [173/173 (100%)]	Average loss: 0.017566
#
# Test set: Average loss: 0.2039, Accuracy: 71/76 (93%)

# %% [markdown]
# ## evaluate

# %%
# %matplotlib inline
outputs, targets = test()
# Out:
# Test set: Average loss: 0.2039, Accuracy: 71/76 (93%)

# %%
imgs = test_set.get_full_data()

logits = np.concatenate(
    outputs
)
sums = np.exp(logits)
probs = sums / sums.sum(axis=1)[:, np.newaxis]
labels = np.concatenate([x.detach().numpy() for x in targets])

# %%
from matplotlib import pyplot as plt

# %%
n_cols = 3
nrows = len(labels) // n_cols
if len(labels) % n_cols:
    nrows+= 1
    
    
fig = plt.figure(figsize=(n_cols,nrows),dpi=200)

for i, (label, prob) in enumerate(zip(labels, probs)):
    plt.subplot(nrows, n_cols, i+1)
    plt.imshow(imgs[i])
    p_dashi = prob[0]
    p_tamag = prob[1]
    answer = {
        0: 'dashi',
        1: 'tamago'
    }[label]
    plt.text(0, 180,
             f"p_tamag={p_tamag:.2}\np_dashi={p_dashi:.2}\nlabel={answer}",
            fontsize=4)
    plt.axis('off')

plt.subplots_adjust(left=1, bottom=0, right=2, top=None, wspace=0.3, hspace=1)
