# %%
import os
import numpy as np
from cnn_finetune import make_model
import pandas as pd
from skimage import io
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import Dataset
from torchvision import transforms, utils

# %% [markdown]
# https://pytorch.org/tutorials/beginner/data_loading_tutorial.html#dataset-class

# %%
model = make_model('vgg11', num_classes=2, pretrained=True, input_size=(128, 128))
device = torch.device('cuda')
model = model.to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg11-bbd30ac9.pth" to /home/kyohei.watarai/.torch/models/vgg11-bbd30ac9.pth
# 100%|██████████| 531456000/531456000 [06:09<00:00, 1439491.12it/s]

# %%
class MyDataSet(Dataset):
    def __init__(self, csv_path, root_dir, transform=None):
        self.data_df = pd.read_csv(csv_path)
        self.root_dir = root_dir
        
        if transform is None:
            self.transform = transforms.Compose([
                transforms.ToTensor(),
                transforms.Normalize(
                mean=model.original_model_info.mean,
                std=model.original_model_info.std),
            ])
        else:
            self.transform = transform
        
    def __len__(self):
        return self.data_df.shape[0]
    
    def __getitem__(self, idx):
        image_name = os.path.join(self.root_dir, self.data_df.iloc[idx, 0])
        image = io.imread(image_name)
        label = self.data_df.iloc[idx, 1]
        return self.transform(image), int(label)
    
    def get_full_data(self):
        image_names = [
            os.path.join(self.root_dir, self.data_df.iloc[idx, 0]) for idx in range(self.data_df.shape[0])
        ]
        images = [io.imread(path) for path in image_names]
        return images

# %%
train_set = MyDataSet('../images/train_data.csv', '../images/resize/data/')
train_loader = torch.utils.data.DataLoader(train_set, shuffle=True)

# %%
test_set = MyDataSet('../images/test_data.csv', '../images/resize/data/')
test_loader = torch.utils.data.DataLoader(test_set, shuffle=False)

# %% [markdown]
# refs
#
# https://github.com/creafz/pytorch-cnn-finetune/blob/master/examples/cifar10.py

# %%
criterion = nn.CrossEntropyLoss()
#optimizer = optim.SGD(model.parameters(), lr=1e-5, momentum=0.9)
optimizer = optim.Adam(model.parameters(), lr=1e-5)

# %%
def train(epoch):
    total_loss = 0
    total_size = 0
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        total_loss += loss.item()
        total_size += data.size(0)
        loss.backward()
        optimizer.step()
        if (batch_idx+1) % 20 == 0 or (batch_idx+1)==len(train_loader):
            progress = 100. * (batch_idx+1) / len(train_loader)
            average_loss = total_loss / total_size
            print(f'Train Epoch: {epoch+1} [{(batch_idx+1) * len(data)}/{len(train_loader.dataset)} ({progress:.0f}%)]\tAverage loss: {average_loss:.6f}')

# %%
def test():
    model.eval()
    test_loss = 0
    correct = 0
    outputs = []
    targets = []
    with torch.no_grad():
        for data, target in test_loader:
            targets.append(target)
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += criterion(output, target).item()
            pred = output.data.max(1, keepdim=True)[1]
            correct += pred.eq(target.data.view_as(pred)).long().cpu().sum().item()
            outputs.append(output.cpu().detach().numpy())

    test_loss /= len(test_loader.dataset)
    accuracy = 100. * correct / len(test_loader.dataset)
    print(f'\nTest set: Average loss: {test_loss:.4f}, Accuracy: {correct}/{len(test_loader.dataset)} ({accuracy:.0f}%)\n')
    return outputs, targets

# %%
for epoch in range(10):
    train(epoch)
    test()
# Out:
# Train Epoch: 1 [20/173 (12%)]	Average loss: 0.649270
# Train Epoch: 1 [40/173 (23%)]	Average loss: 0.664039
# Train Epoch: 1 [60/173 (35%)]	Average loss: 0.706263
# Train Epoch: 1 [80/173 (46%)]	Average loss: 0.683746
# Train Epoch: 1 [100/173 (58%)]	Average loss: 0.662302
# Train Epoch: 1 [120/173 (69%)]	Average loss: 0.644052
# Train Epoch: 1 [140/173 (81%)]	Average loss: 0.622147
# Train Epoch: 1 [160/173 (92%)]	Average loss: 0.589234
# Train Epoch: 1 [173/173 (100%)]	Average loss: 0.572832
#
# Test set: Average loss: 0.3811, Accuracy: 63/76 (83%)
#
# Train Epoch: 2 [20/173 (12%)]	Average loss: 0.282193
# Train Epoch: 2 [40/173 (23%)]	Average loss: 0.251722
# Train Epoch: 2 [60/173 (35%)]	Average loss: 0.231606
# Train Epoch: 2 [80/173 (46%)]	Average loss: 0.221606
# Train Epoch: 2 [100/173 (58%)]	Average loss: 0.208849
# Train Epoch: 2 [120/173 (69%)]	Average loss: 0.189591
# Train Epoch: 2 [140/173 (81%)]	Average loss: 0.208643
# Train Epoch: 2 [160/173 (92%)]	Average loss: 0.209681
# Train Epoch: 2 [173/173 (100%)]	Average loss: 0.203349
# Train Epoch: 7 [160/173 (92%)]	Average loss: 0.005032
# Train Epoch: 7 [173/173 (100%)]	Average loss: 0.004714
#
# Test set: Average loss: 0.2576, Accuracy: 70/76 (92%)
#
# Train Epoch: 8 [20/173 (12%)]	Average loss: 0.000537
# Train Epoch: 8 [40/173 (23%)]	Average loss: 0.000398
# Train Epoch: 8 [60/173 (35%)]	Average loss: 0.002567
# Train Epoch: 8 [80/173 (46%)]	Average loss: 0.002241
# Train Epoch: 8 [100/173 (58%)]	Average loss: 0.001889
# Train Epoch: 8 [120/173 (69%)]	Average loss: 0.001614
# Train Epoch: 8 [140/173 (81%)]	Average loss: 0.001413
# Train Epoch: 8 [160/173 (92%)]	Average loss: 0.001312
# Train Epoch: 8 [173/173 (100%)]	Average loss: 0.001342
#
# Test set: Average loss: 0.2620, Accuracy: 71/76 (93%)
#
# Train Epoch: 9 [20/173 (12%)]	Average loss: 0.000311
# Train Epoch: 9 [40/173 (23%)]	Average loss: 0.000553
# Train Epoch: 9 [60/173 (35%)]	Average loss: 0.002153
# Train Epoch: 9 [80/173 (46%)]	Average loss: 0.001758
# Train Epoch: 9 [100/173 (58%)]	Average loss: 0.001455
# Train Epoch: 9 [120/173 (69%)]	Average loss: 0.001406
# Train Epoch: 9 [140/173 (81%)]	Average loss: 0.001229
# Train Epoch: 9 [160/173 (92%)]	Average loss: 0.001098
# Train Epoch: 9 [173/173 (100%)]	Average loss: 0.001060
#
# Test set: Average loss: 0.2690, Accuracy: 71/76 (93%)
#
# Train Epoch: 10 [20/173 (12%)]	Average loss: 0.001720
# Train Epoch: 10 [40/173 (23%)]	Average loss: 0.001357
# Train Epoch: 10 [60/173 (35%)]	Average loss: 0.000971
# Train Epoch: 10 [80/173 (46%)]	Average loss: 0.001274
# Train Epoch: 10 [100/173 (58%)]	Average loss: 0.001059
# Train Epoch: 10 [120/173 (69%)]	Average loss: 0.000906
# Train Epoch: 10 [140/173 (81%)]	Average loss: 0.000814
# Train Epoch: 10 [160/173 (92%)]	Average loss: 0.000728
# Train Epoch: 10 [173/173 (100%)]	Average loss: 0.001042
#
# Test set: Average loss: 0.2809, Accuracy: 71/76 (93%)

# %% [markdown]
# ## evaluate

# %%
# %matplotlib inline
outputs, targets = test()
# Out:
# Test set: Average loss: 0.2809, Accuracy: 71/76 (93%)

# %%
imgs = test_set.get_full_data()

logits = np.concatenate(
    outputs
)
sums = np.exp(logits)
probs = sums / sums.sum(axis=1)[:, np.newaxis]
labels = np.concatenate([x.detach().numpy() for x in targets])

# %%
from matplotlib import pyplot as plt

# %%
n_cols = 3
nrows = len(labels) // n_cols
if len(labels) % n_cols:
    nrows+= 1
    
    
fig = plt.figure(figsize=(n_cols,nrows),dpi=200)

for i, (label, prob) in enumerate(zip(labels, probs)):
    plt.subplot(nrows, n_cols, i+1)
    plt.imshow(imgs[i])
    p_dashi = prob[0]
    p_tamag = prob[1]
    answer = {
        0: 'dashi',
        1: 'tamago'
    }[label]
    plt.text(0, 180,
             f"p_tamag={p_tamag:.2}\np_dashi={p_dashi:.2}\nlabel={answer}",
            fontsize=4)
    plt.axis('off')

plt.subplots_adjust(left=1, bottom=0, right=2, top=None, wspace=0.3, hspace=1)
